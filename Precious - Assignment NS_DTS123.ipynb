# %%
#NUMPY ASSIGNMENT

#Topic: NumPy Arrays, Boolean Filtering, "np.where()", and Missing Values.

#QUESTION 1 — Array Analysis
import numpy as np
Scores = np.array([42,67,85,31,74,93,56,48,79,61,37,88])

# %%
# Question 1- No:A  
print(Scores)
# Out:
# [42 67 85 31 74 93 56 48 79 61 37 88]

# %%
# Question 1No:B 
print(Scores)
# Out:
# [42 67 85 31 74 93 56 48 79 61 37 88]

# %%
# Question 1 No:C 
print(np.max(Scores))
# Out:
# 93

# %%
# Question 1 No:D 
print(np.min(Scores))
# Out:
# 31

# %%
# Question 1 No:E
print(np.sum(Scores))
# Out:
# 761

# %%
# Question 1 No:F  
print(np.mean(Scores))
# Out:
# 63.416666666666664

# %%
# Question 1 No: G
print(Scores[Scores >= 60])
# Out:
# [67 85 74 93 79 61 88]

# %%
# Question 1  No: H
print(Scores[Scores <= 50])
# Out:
# [42 31 48 37]

# %%
# Question 1 No: I
print(np.sum(Scores <= 50))
# Out:
# 4

# %%
# QUESTION 2 no: a
print( Scores > 60)
# Out:
# [False  True  True False  True  True False False  True  True False  True]

# %%
#QUESTION 2 no: b

print( Scores [Scores >= 60])
# Out:
# [67 85 74 93 79 61 88]

# %%
#QUESTION 2 no:c

print( Scores [(Scores >= 60) & (Scores < 80)])
# Out:
# [67 74 79 61]

# %%
#QUESTION 2 no:d

print( Scores [Scores >= 80])
# Out:
# [85 93 88]

# %%
#QUESTION 2 no:e

print( Scores [Scores <= 40])
# Out:
# [31 37]

# %%
#QUESTION 2 no: f
print( Scores [Scores <= 60])
# Out:
# [42 31 56 48 37]

# %%
#QUESTION 2 - no:g

print( Scores [(Scores >= 80) | (Scores < 40)])
# Out:
# [85 31 93 37 88]

# %%
#QUESTION 2 no: h

print( Scores [(Scores >= 60) & (Scores < 90)])
# Out:
# [67 85 74 79 61 88]

# %%
# QUESTION 3 - NP.WHERE()

#Q No: A
result = np.where (Scores >= 50, "pass", "fail")
print(result)
# Out:
# ['fail' 'pass' 'pass' 'fail' 'pass' 'pass' 'pass' 'fail' 'pass' 'pass'
#  'fail' 'pass']

# %%
# QUESTION 3 No: B

import numpy as np
Scores = np.array([42,67,85,31,74,93,56,48,79,61,37,88])

result = np.where(Scores >= 80, "execellent", "Not Execellent")
print(result)
# Out:
# ['Not Execellent' 'Not Execellent' 'execellent' 'Not Execellent'
#  'Not Execellent' 'execellent' 'Not Execellent' 'Not Execellent'
#  'Not Execellent' 'Not Execellent' 'Not Execellent' 'execellent']

# %%
# QUESTION 3 No: C

grade = np.where(
    Scores >= 70, "A",
    np.where(
        Scores >= 60, "B",
        np.where( 
            Scores >= 50 , "C", "F"
        )
    )
)
print(grade)
# Out:
# ['F' 'B' 'A' 'F' 'A' 'A' 'C' 'F' 'A' 'B' 'F' 'A']

# %%
# QUESTION 4 - Challenge: Multiple Conditions

import numpy as np

Result = np.array([35,52,68,74,81,45,59,92,63,39,77,86])
print(Result)
# Out:
# [35 52 68 74 81 45 59 92 63 39 77 86]

# %%
# QUESTION 4 No: A

print(Result [Result >=70])
# Out:
# [74 81 92 77 86]

# %%
# QUESTION 4 No: B

print(Result [(Result > 40) & (Result < 70)])
# Out:
# [52 68 45 59 63]

# %%
# QUESTION 4 No: C

print(Result [(Result < 40) | (Result > 70)])
# Out:
# [35 74 81 92 39 77 86]

# %%
# QUESTION 4 No: D

print(Result [(Result > 50) & (Result < 80)])
# Out:
# [52 68 74 59 63 77]

# %%
# QUESTION 4 No: E
print(np.sum((Result > 50) & (Result < 80)))
# Out:
# 6

# %%
# QUESTION 4 No: F 
print(np.sum((Result > 70)))
# Out:
# 5

# %%
# QUESTION 4 No: G
print(np.mean(Result [Result > 70]))
# Out:
# 82.0

# %%
# QUESTION 5 - Grade Analysis Without Loops

import numpy as np

Results = np.array([35,52,68,74,81,45,59,92,63,39,77,86])
print(Results)

grade = np.where(
     Results >= 70, "A",
    np.where(
        Results >= 60, "B",
        np.where( 
            Results >= 50 , "C", "F"
        )
    )
)
print("\n", grade)
# Out:
# [35 52 68 74 81 45 59 92 63 39 77 86]
#
#  ['F' 'C' 'B' 'A' 'A' 'F' 'C' 'A' 'B' 'F' 'A' 'A']

# %%
#Question 5 no: A
print(np.sum(Results > 50))
# Out:
# 9

# %%
#Question 5 no: B
print(np.sum(Results < 50))
# Out:
# 3

# %%
#Question 5 no: C
print(np.sum(grade == "A"))
# Out:
# 5

# %%
#Question 5 no: D
print(np.sum(grade == "B"))
# Out:
# 2

# %%
#Question 5 no: E
print(np.sum(grade == "C"))
# Out:
# 2

# %%
#Question 5 no: F
print(np.max(Results))
# Out:
# 92

# %%
#Question 5 no: G
print(np.min(Results))
# Out:
# 35

# %%
#Question 5 no: H
print(np.mean(Results))
# Out:
# 64.25

# %%
#QUESTION 6 - MISSING VALUES

import numpy as np

Nums = np.array([45,67,np.nan,82,54,np.nan,71,39,90,np.nan,63])

# %%
#QUESTION 6 no: A
print(Nums)
# Out:
# [45. 67. nan 82. 54. nan 71. 39. 90. nan 63.]

# %%
#QUESTION 6 no: B
print(np.isnan(Nums))
# Out:
# [False False  True False False  True False False False  True False]

# %%
#QUESTION 6 no: C
print(Nums[np.isnan(Nums)])
# Out:
# [nan nan nan]

# %%
#QUESTION 6 no: D

Average_Nums = np.nanmean(Nums)
print(Average_Nums)
# Out:
# 63.875

# %%
#QUESTION 6 no: E

Average_Nums = np.nanmax(Nums)
print(Average_Nums)
# Out:
# 90.0

# %%
#QUESTION 6 no: F

Average_Nums = np.nanmin(Nums)
print(Average_Nums)
# Out:
# 39.0

# %%
#QUESTION 6 no: G


import numpy as np

Nums = np.array([45,67,np.nan,82,54,np.nan,71,39,90,np.nan,63])
Nums_no =np.copy (Nums)
Nums_no[np.isnan(Nums_no)]
# Out:
# array([nan, nan, nan])

# %%
#QUESTION 6 no: H
print(Nums_no)
# Out:
# [45. 67. nan 82. 54. nan 71. 39. 90. nan 63.]

# %%
#Question 7 - Final Challenge

import numpy as np

Recoreded = np.array([29,47,51,64,72,88,np.nan,93,56,41,np.nan,79,67,35,84])

# %%
#QUESTION 7 no: 1
print(Recoreded)
# Out:
# [29. 47. 51. 64. 72. 88. nan 93. 56. 41. nan 79. 67. 35. 84.]

# %%
#Question 7 No: 2
print(np.isnan(Recoreded))
# Out:
# [False False False False False False  True False False False  True False
#  False False False]

# %%
#Question 7 No: 3
print(np.nanmean(Recoreded))
# Out:
# 62.0

# %%
#Question 7 No: 4
updata_Recored =np.copy (Recoreded)
updata_Recored [np.isnan(Recoreded)]
# Out:
# array([nan, nan])

# %%
#Question 7 No: 5
print(updata_Recored)
# Out:
# [29. 47. 51. 64. 72. 88. nan 93. 56. 41. nan 79. 67. 35. 84.]

# %%
#Question 7 No: 6
Recoreded = np.where (Scores >= 50, "pass", "fail")
print(Recoreded)
# Out:
# ['fail' 'pass' 'pass' 'fail' 'pass' 'pass' 'pass' 'fail' 'pass' 'pass'
#  'fail' 'pass']

# %%
#Question No: 7

import numpy as np

Recoreded = np.array([29,47,51,64,72,88,np.nan,93,56,41,np.nan,79,67,35,84])

grade =np.where(
  Recoreded > 70, "A",
    np.where(
        Recoreded > 60, "B",
        np.where(
            Recoreded > 50, "C", "F"
        )
    )
)
print(grade)
# Out:
# ['F' 'F' 'C' 'B' 'A' 'A' 'F' 'A' 'C' 'F' 'F' 'A' 'B' 'F' 'A']

# %%
#Question 7 No: 8

print(Recoreded [Recoreded > 70])
# Out:
# [72. 88. 93. 79. 84.]

# %%
#Question 7 No: 9

print(Recoreded [Recoreded < 50])
# Out:
# [29. 47. 41. 35.]

# %%
#Question 7 No: 10

print(np.nanmax (Recoreded))
# Out:
# 93.0

# %%
#Question 7 No: 11

print(np.nanmin (Recoreded))
# Out:
# 29.0

# %%
#Question 7 No: 12

print(np.nanmean (Recoreded))
# Out:
# 62.0

# %%
#Question 7 No: 13

print(np.nansum (Recoreded > 50))
# Out:
# 9

# %%
#Question 7 No: 14

print(np.nansum (Recoreded < 50))
# Out:
# 4

# %%
#Additional Requirement

#Q1 Answer - In my understanding it's applies a logical mask to extract and return a shorter array containing only the matching valuse, Whille Np.where() performs element wise cinditional transformation the original shape and size of the array.

#Q2 Answer- Np.where() Any arithmetic operation involoving an underfined value, Whille Np.nanmean() Do the Calulates the class average based strictly on the parers that were actully graded.

#Q3 Answers - This mean that the value it's replacing missing entries with 0 introduces extreme downward bias into your dataset.
